# %%
from urllib import request

url = "https://www.gutenberg.org/files/17989/17989-0.txt"
response = request.urlopen(url)
raw = response.read().decode("utf8")

dumas = raw.split(
    "*** START OF THE PROJECT GUTENBERG EBOOK LE COMTE DE MONTE-CRISTO, TOME I ***"
)[1].split(
    "*** END OF THE PROJECT GUTENBERG EBOOK LE COMTE DE MONTE-CRISTO, TOME I ***"
)[
    0
]

import re


def clean_text(text):
    text = text.lower()  # mettre les mots en minuscule
    text = " ".join(text.split())
    return text


dumas = clean_text(dumas)

dumas[10000:10500]
# Out:
# " mes yeux. --vous avez donc vu l'empereur aussi? --il est entré chez le maréchal pendant que j'y étais. --et vous lui avez parlé? --c'est-à-dire que c'est lui qui m'a parlé, monsieur, dit dantès en souriant. --et que vous a-t-il dit? --il m'a fait des questions sur le bâtiment, sur l'époque de son départ pour marseille, sur la route qu'il avait suivie et sur la cargaison qu'il portait. je crois que s'il eût été vide, et que j'en eusse été le maître, son intention eût été de l'acheter; mais je lu"

# %%
import wordcloud
import numpy as np
import io
import requests
import PIL
import matplotlib.pyplot as plt

img = "https://minio.lab.sspcloud.fr/lgaliana/generative-art/pythonds/book.png"
book_mask = np.array(PIL.Image.open(io.BytesIO(requests.get(img).content)))


def make_wordcloud(corpus):
    wc = wordcloud.WordCloud(
        background_color="white",
        max_words=2000,
        mask=book_mask,
        contour_width=3,
        contour_color="steelblue",
    )
    wc.generate(corpus)
    return wc


wordcloud_dumas = make_wordcloud(dumas)

# %%
plt.imshow(wordcloud_dumas, interpolation="bilinear")
plt.axis("off")
# Out:
# (-0.5, 1429.5, 783.5, -0.5)

# %%
import nltk

nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\yzi\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
import nltk

words = nltk.word_tokenize(dumas, language="french")
words[1030:1050]
# Out:
# ['que',
#  'voulez-vous',
#  ',',
#  'monsieur',
#  'edmond',
#  ',',
#  'reprit',
#  "l'armateur",
#  'qui',
#  'paraissait',
#  'se',
#  'consoler',
#  'de',
#  'plus',
#  'en',
#  'plus',
#  ',',
#  'nous',
#  'sommes',
#  'tous']

# %%
words = [word for word in words if word.isalpha()]
words[1030:1050]
# Out:
# ['assez',
#  'sombre',
#  'obséquieux',
#  'envers',
#  'ses',
#  'supérieurs',
#  'insolent',
#  'envers',
#  'ses',
#  'subordonnés',
#  'aussi',
#  'outre',
#  'son',
#  'titre',
#  'comptable',
#  'qui',
#  'est',
#  'toujours',
#  'un',
#  'motif']

# %%
import nltk

nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\yzi\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
from nltk.corpus import stopwords

print(stopwords.words("french"))

stop_words = set(stopwords.words("french"))


words = [w for w in words if not w in stop_words]
print(words[1030:1050])
# Out:
# ['au', 'aux', 'avec', 'ce', 'ces', 'dans', 'de', 'des', 'du', 'elle', 'en', 'et', 'eux', 'il', 'ils', 'je', 'la', 'le', 'les', 'leur', 'lui', 'ma', 'mais', 'me', 'même', 'mes', 'moi', 'mon', 'ne', 'nos', 'notre', 'nous', 'on', 'ou', 'par', 'pas', 'pour', 'qu', 'que', 'qui', 'sa', 'se', 'ses', 'son', 'sur', 'ta', 'te', 'tes', 'toi', 'ton', 'tu', 'un', 'une', 'vos', 'votre', 'vous', 'c', 'd', 'j', 'l', 'à', 'm', 'n', 's', 't', 'y', 'été', 'étée', 'étées', 'étés', 'étant', 'étante', 'étants', 'étantes', 'suis', 'es', 'est', 'sommes', 'êtes', 'sont', 'serai', 'seras', 'sera', 'serons', 'serez', 'seront', 'serais', 'serait', 'serions', 'seriez', 'seraient', 'étais', 'était', 'étions', 'étiez', 'étaient', 'fus', 'fut', 'fûmes', 'fûtes', 'furent', 'sois', 'soit', 'soyons', 'soyez', 'soient', 'fusse', 'fusses', 'fût', 'fussions', 'fussiez', 'fussent', 'ayant', 'ayante', 'ayantes', 'ayants', 'eu', 'eue', 'eues', 'eus', 'ai', 'as', 'avons', 'avez', 'ont', 'aurai', 'auras', 'aura', 'aurons', 'aurez', 'auront', 'aurais', 'aurait', 'aurions', 'auriez', 'auraient', 'avais', 'avait', 'avions', 'aviez', 'avaient', 'eut', 'eûmes', 'eûtes', 'eurent', 'aie', 'aies', 'ait', 'ayons', 'ayez', 'aient', 'eusse', 'eusses', 'eût', 'eussions', 'eussiez', 'eussent']
# ['celui', 'dantès', 'a', 'déposé', 'passant', 'comment', 'paquet', 'déposer', 'danglars', 'rougit', 'passais', 'devant', 'porte', 'capitaine', 'entrouverte', 'vu', 'remettre', 'paquet', 'cette', 'lettre']

# %%
wc = make_wordcloud(" ".join(words))

fig = plt.figure()

plt.imshow(wc, interpolation="bilinear")
plt.axis("off")
# Out:
# (-0.5, 1429.5, 783.5, -0.5)

# %%
from nltk.stem.snowball import SnowballStemmer

stemmer = SnowballStemmer(language="french")

stemmed = [stemmer.stem(word) for word in words]
print(stemmed[1030:1050])
# Out:
# ['celui', 'dantes', 'a', 'dépos', 'pass', 'comment', 'paquet', 'dépos', 'danglar', 'roug', 'pass', 'dev', 'port', 'capitain', 'entrouvert', 'vu', 'remettr', 'paquet', 'cet', 'lettr']

# %%
# !pip install deplacy spacy
# !python -m spacy download fr_core_news_sm
import spacy
import spacy
from spacy import displacy

nlp=spacy.load("fr_core_news_sm")
doc = nlp(dumas[15000:17000])
displacy.render(doc, style="ent", jupyter=True)
# Out:
# Requirement already satisfied: deplacy in c:\users\yzi\appdata\roaming\python\python39\lib\site-packages (2.1.0)
# Collecting spacy
#   Downloading spacy-3.7.4-cp39-cp39-win_amd64.whl (12.2 MB)
#      ---------------------------------------- 12.2/12.2 MB 9.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.19.0 in c:\users\yzi\appdata\roaming\python\python39\lib\site-packages (from spacy) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\yzi\appdata\roaming\python\python39\site-packages (from spacy) (24.0)
# Collecting langcodes<4.0.0,>=3.2.0
#   Downloading langcodes-3.3.0-py3-none-any.whl (181 kB)
#      -------------------------------------- 181.6/181.6 KB 5.4 MB/s eta 0:00:00
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Collecting thinc<8.3.0,>=8.2.2
#   Downloading thinc-8.2.3-cp39-cp39-win_amd64.whl (1.5 MB)
#      ---------------------------------------- 1.5/1.5 MB 8.6 MB/s eta 0:00:00
# Collecting spacy-legacy<3.1.0,>=3.0.11
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Collecting weasel<0.4.0,>=0.1.0
#   Downloading weasel-0.3.4-py3-none-any.whl (50 kB)
#      ---------------------------------------- 50.1/50.1 KB 2.5 MB/s eta 0:00:00
# Collecting typer<0.10.0,>=0.3.0
#   Downloading typer-0.9.4-py3-none-any.whl (45 kB)
#      ---------------------------------------- 46.0/46.0 KB ? eta 0:00:00
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\yzi\appdata\roaming\python\python39\lib\site-packages (from spacy) (2.31.0)
# Collecting smart-open<7.0.0,>=5.2.1
#   Downloading smart_open-6.4.0-py3-none-any.whl (57 kB)
#      ---------------------------------------- 57.0/57.0 KB ? eta 0:00:00
# Collecting srsly<3.0.0,>=2.4.3
#   Downloading srsly-2.4.8-cp39-cp39-win_amd64.whl (483 kB)
#      -------------------------------------- 483.8/483.8 KB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in c:\users\yzi\appdata\roaming\python\python39\lib\site-packages (from spacy) (58.1.0)
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.8-cp39-cp39-win_amd64.whl (39 kB)
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.10-cp39-cp39-win_amd64.whl (25 kB)
# Collecting pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4
#   Downloading pydantic-2.7.0-py3-none-any.whl (407 kB)
#      ------------------------------------- 407.9/407.9 KB 12.8 MB/s eta 0:00:00
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.9-cp39-cp39-win_amd64.whl (122 kB)
#      ---------------------------------------- 122.7/122.7 KB ? eta 0:00:00
# Collecting catalogue<2.1.0,>=2.0.6
#   Downloading catalogue-2.0.10-py3-none-any.whl (17 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\yzi\appdata\roaming\python\python39\lib\site-packages (from spacy) (4.66.2)
# Collecting wasabi<1.2.0,>=0.9.1
#   Downloading wasabi-1.1.2-py3-none-any.whl (27 kB)
# Collecting jinja2
#   Using cached Jinja2-3.1.3-py3-none-any.whl (133 kB)
# Collecting annotated-types>=0.4.0
#   Using cached annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Collecting pydantic-core==2.18.1
#   Downloading pydantic_core-2.18.1-cp39-none-win_amd64.whl (1.9 MB)
#      ---------------------------------------- 1.9/1.9 MB 7.6 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\yzi\appdata\roaming\python\python39\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.11.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\yzi\appdata\roaming\python\python39\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\yzi\appdata\roaming\python\python39\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\yzi\appdata\roaming\python\python39\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.2.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\yzi\appdata\roaming\python\python39\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Collecting blis<0.8.0,>=0.7.8
#   Downloading blis-0.7.11-cp39-cp39-win_amd64.whl (6.6 MB)
#      ---------------------------------------- 6.6/6.6 MB 11.4 MB/s eta 0:00:00
# Collecting confection<1.0.0,>=0.0.1
#   Downloading confection-0.1.4-py3-none-any.whl (35 kB)
# Requirement already satisfied: colorama in c:\users\yzi\appdata\roaming\python\python39\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\yzi\appdata\roaming\python\python39\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.7)
# Collecting cloudpathlib<0.17.0,>=0.7.0
#   Downloading cloudpathlib-0.16.0-py3-none-any.whl (45 kB)
#      ---------------------------------------- 45.0/45.0 KB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\yzi\appdata\roaming\python\python39\lib\site-packages (from jinja2->spacy) (2.1.5)
# Installing collected packages: cymem, wasabi, spacy-loggers, spacy-legacy, smart-open, pydantic-core, murmurhash, langcodes, jinja2, cloudpathlib, catalogue, blis, annotated-types, typer, srsly, pydantic, preshed, confection, weasel, thinc, spacy
# Successfully installed annotated-types-0.6.0 blis-0.7.11 catalogue-2.0.10 cloudpathlib-0.16.0 confection-0.1.4 cymem-2.0.8 jinja2-3.1.3 langcodes-3.3.0 murmurhash-1.0.10 preshed-3.0.9 pydantic-2.7.0 pydantic-core-2.18.1 smart-open-6.4.0 spacy-3.7.4 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.4.8 thinc-8.2.3 typer-0.9.4 wasabi-1.1.2 weasel-0.3.4
# WARNING: You are using pip version 22.0.4; however, version 24.0 is available.
# You should consider upgrading via the 'C:\Users\yzi\AppData\Roaming\Python\Python39\python.exe -m pip install --upgrade pip' command.
# WARNING: You are using pip version 22.0.4; however, version 24.0 is available.
# You should consider upgrading via the 'c:\Users\yzi\AppData\Roaming\Python\Python39\python.exe -m pip install --upgrade pip' command.
# Collecting fr-core-news-sm==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/fr_core_news_sm-3.7.0/fr_core_news_sm-3.7.0-py3-none-any.whl (16.3 MB)
#      --------------------------------------- 16.3/16.3 MB 10.7 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in c:\users\yzi\appdata\roaming\python\python39\lib\site-packages (from fr-core-news-sm==3.7.0) (3.7.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\yzi\appdata\roaming\python\python39\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (24.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\yzi\appdata\roaming\python\python39\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.0.10)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\yzi\appdata\roaming\python\python39\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.26.4)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\yzi\appdata\roaming\python\python39\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.0.8)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\yzi\appdata\roaming\python\python39\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.3.4)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\yzi\appdata\roaming\python\python39\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.1.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\yzi\appdata\roaming\python\python39\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.0.12)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\yzi\appdata\roaming\python\python39\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.0.10)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\yzi\appdata\roaming\python\python39\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.0.5)
# Requirement already satisfied: jinja2 in c:\users\yzi\appdata\roaming\python\python39\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.1.3)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\yzi\appdata\roaming\python\python39\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (6.4.0)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\yzi\appdata\roaming\python\python39\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.9.4)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\yzi\appdata\roaming\python\python39\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.3.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\yzi\appdata\roaming\python\python39\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.0.9)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\yzi\appdata\roaming\python\python39\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.7.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\yzi\appdata\roaming\python\python39\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.31.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\yzi\appdata\roaming\python\python39\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (4.66.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\yzi\appdata\roaming\python\python39\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.4.8)
# Requirement already satisfied: setuptools in c:\users\yzi\appdata\roaming\python\python39\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (58.1.0)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\yzi\appdata\roaming\python\python39\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (8.2.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\yzi\appdata\roaming\python\python39\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (4.11.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\yzi\appdata\roaming\python\python39\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.1 in c:\users\yzi\appdata\roaming\python\python39\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.18.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\yzi\appdata\roaming\python\python39\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\yzi\appdata\roaming\python\python39\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\yzi\appdata\roaming\python\python39\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2024.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\yzi\appdata\roaming\python\python39\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.3.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\yzi\appdata\roaming\python\python39\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\yzi\appdata\roaming\python\python39\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.1.4)
# Requirement already satisfied: colorama in c:\users\yzi\appdata\roaming\python\python39\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\yzi\appdata\roaming\python\python39\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\yzi\appdata\roaming\python\python39\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\yzi\appdata\roaming\python\python39\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.1.5)
# Installing collected packages: fr-core-news-sm
# Successfully installed fr-core-news-sm-3.7.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('fr_core_news_sm')
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     us
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  donne tout loisir de faire les vôtres.
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     avez
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# -vous besoin d'argent? --non, monsieur; j'ai tous mes appointements du voyage, c'est-à-dire près de trois mois de solde. --vous êtes un garçon rangé,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     edmond.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  --ajoutez que j'ai un père pauvre, monsieur morrel. --oui, oui, je sais que vous êtes un bon fils. allez donc voir votre père: j'ai un fils aussi, et j'en voudrais fort à celui qui, après un voyage de trois mois, le retiendrait loin de moi. --alors, vous permettez? dit le jeune homme en saluant. --oui, si vous n'avez rien de plus à me dire.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     --non
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# . --le capitaine leclère ne vous a pas, en mourant, donné une lettre pour moi? --il lui eût été impossible d'écrire, monsieur; mais cela me rappelle que j'aurai un congé de quinze jours à vous demander. --pour vous marier? --d'abord; puis pour aller à
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     paris
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# . --bon, bon! vous prendrez le temps que vous voudrez, dantès; le temps de décharger le bâtiment nous prendra bien six semaines, et nous ne nous remettrons guère en mer avant trois mois.... seulement, dans trois mois, il faudra que vous soyez là. le _pharaon_, continua l'armateur en frappant sur l'épaule du jeune marin, ne pourrait pas repartir sans son capitaine. --sans son capitaine! s'écria dantès les yeux brillants de joie; faites bien attention à ce que vous dites là, monsieur, car vous venez de répondre aux plus secrètes espérances de mon coeur. votre intention serait-elle de me nommer capitaine du _pharaon_? --si j'étais seul, je vous tendrais la main, mon cher
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     dantès
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , et je vous dirais: «c'est fait.» mais j'ai un associé, et vous savez le proverbe italien: _che a compagne a padrone_. mais la moitié de la
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     besogne
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  est faite au moins, puisque sur deux voix vous en avez déjà une. rapportez-vous-en à moi pour avoir l'autre, et je ferai de mon mieux.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     --oh!
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  monsieur morrel, s'écria le jeune marin, saisissant, les larmes aux yeux, les mains de l'armateur; monsieur morrel, je vous remercie, au nom de mon père et de mercédès.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     --c'
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# est bien, c'est bien, edmond, il y a un dieu </div></span>
